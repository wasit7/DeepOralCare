# %%
import pandas as pd
import dask.dataframe as dd

# %%
from searchapp.models import *

# %%
df = pd.read_csv("../data/raw-kg.csv", low_memory=False)

# %%
df
# Out:
#                        relation   display_relation  x_index  x_id  \
# 0               protein_protein                ppi        0  9796
# 1               protein_protein                ppi        1  7918
# 2               protein_protein                ppi        2  8233
# 3               protein_protein                ppi        3  4899
# 4               protein_protein                ppi        4  5297
# ...                         ...                ...      ...   ...
# 8100493  anatomy_protein_absent  expression absent    66747  4720
# 8100494  anatomy_protein_absent  expression absent    63824  1377
# 8100495  anatomy_protein_absent  expression absent    63826  1379
# 8100496  anatomy_protein_absent  expression absent    64523  2084
# 8100497  anatomy_protein_absent  expression absent    67302  5384
#
#                x_type                   x_name x_source  y_index       y_id  \
# 0        gene/protein                   PHYHIP     NCBI     8889      56992
# ...

# %%
df.query('x_type=="disease"')
# Out:
#                            relation  display_relation  x_index  \
# 3084053  disease_phenotype_negative  phenotype absent    27158
# 3084054  disease_phenotype_negative  phenotype absent    27158
# 3084055  disease_phenotype_negative  phenotype absent    27159
# 3084056  disease_phenotype_negative  phenotype absent    27159
# 3084057  disease_phenotype_negative  phenotype absent    27159
# ...                             ...               ...      ...
# 6499510            exposure_disease         linked to    31393
# 6499511            exposure_disease         linked to    28208
# 6499512            exposure_disease         linked to    84172
# 6499513            exposure_disease         linked to    33063
# 6499514            exposure_disease         linked to    28668
#
#                                                       x_id   x_type  \
# 3084053  13924_12592_14672_13460_12591_12536_30861_8146...  disease
# 3084054  13924_12592_14672_13460_12591_12536_30861_8146...  disease
# ...
